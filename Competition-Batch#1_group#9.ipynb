# %% [markdown]
# This is a Women’s Clothing E-Commerce dataset revolving around the reviews written by customers. Its nine supportive features offer a great environment to parse out the text through its multiple dimensions. Because this is real commercial data, it has been anonymized, and references to the company in the review text and body have been replaced with “retailer”.

# %% [markdown]
# This dataset includes 23486 rows and 10 feature variables. Each row corresponds to a customer review, and includes the variables:
# *Clothing ID: Integer Categorical variable that refers to the specific piece being reviewed.
# *Age: Positive Integer variable of the reviewers age.
# *Title: String variable for the title of the review.
# *Review Text: String variable for the review body.
# *Rating: Positive Ordinal Integer variable for the product score granted by the customer from 1 Worst, to 5 Best.
# *Recommended IND: Binary variable stating where the customer recommends the product where 1 is recommended, 0 is not   recommended.
# *Positive Feedback Count: Positive Integer documenting the number of other customers who found this review positive.
# *Division Name: Categorical name of the product high level division.
# *Department Name: Categorical name of the product department name.
# *Class Name: Categorical name of the product class name.

# %%
#importing packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#calling dataset into python environment.
data=pd.read_csv(r'C:\Users\Admin\Downloads\womens clothing.csv')
data.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33                      NaN
# 1           1         1080   34                      NaN
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
# 4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses

# %%
data.tail()
# Out:
#        Unnamed: 0  Clothing ID  Age  \
# 23481       23481         1104   34
# 23482       23482          862   48
# 23483       23483         1104   31
# 23484       23484         1084   28
# 23485       23485         1104   52
#
#                                                    Title  \
# 23481                     Great dress for many occasions
# 23482                         Wish it was made of cotton
# 23483                              Cute, but see through
# 23484  Very cute dress, perfect for summer parties an...
# 23485                    Please make more like this one!
#
#                                              Review Text  Rating  \
# 23481  I was very happy to snag this dress at such a ...       5
# 23482  It reminds me of maternity clothes. soft, stre...       3
# 23483  This fit well, but the top was very see throug...       3
# 23484  I bought this dress for a wedding i have this ...       3
# 23485  This dress in a lovely platinum is feminine an...       5
#
#        Recommended IND  Positive Feedback Count   Division Name  \
# 23481                1                        0  General Petite
# 23482                1                        0  General Petite
# 23483                0                        1  General Petite
# 23484                1                        2         General
# 23485                1                       22  General Petite
#
#       Department Name Class Name
# 23481         Dresses    Dresses
# 23482            Tops      Knits
# 23483         Dresses    Dresses
# 23484         Dresses    Dresses
# 23485         Dresses    Dresses

# %%
#the basic information about data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23486 entries, 0 to 23485
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               23486 non-null  int64
#  1   Clothing ID              23486 non-null  int64
#  2   Age                      23486 non-null  int64
#  3   Title                    19676 non-null  object
#  4   Review Text              22641 non-null  object
#  5   Rating                   23486 non-null  int64
#  6   Recommended IND          23486 non-null  int64
#  7   Positive Feedback Count  23486 non-null  int64
#  8   Division Name            23472 non-null  object
#  9   Department Name          23472 non-null  object
#  10  Class Name               23472 non-null  object
# dtypes: int64(6), object(5)
# memory usage: 2.0+ MB

# %%
#shape of the dataset
data.shape
# Out:
# (23486, 11)

# %% [markdown]
# There are 23486 rows and 11 columns in the dataset before preprocessing.

# %%
#column names
data.columns
# Out:
# Index(['Unnamed: 0', 'Clothing ID', 'Age', 'Title', 'Review Text', 'Rating',
#        'Recommended IND', 'Positive Feedback Count', 'Division Name',
#        'Department Name', 'Class Name'],
#       dtype='object')

# %%
#dropping the 'Unnamed: 0' column.
data.drop('Unnamed: 0',inplace=True,axis=1)

# %%
data.head(2)
# Out:
#    Clothing ID  Age Title                                        Review Text  \
# 0          767   33   NaN  Absolutely wonderful - silky and sexy and comf...
# 1         1080   34   NaN  Love this dress!  it's sooo pretty.  i happene...
#
#    Rating  Recommended IND  Positive Feedback Count Division Name  \
# 0       4                1                        0     Initmates
# 1       5                1                        4       General
#
#   Department Name Class Name
# 0        Intimate  Intimates
# 1         Dresses    Dresses

# %%
#statistics
data.describe()
# Out:
#         Clothing ID           Age        Rating  Recommended IND  \
# count  23486.000000  23486.000000  23486.000000     23486.000000
# mean     918.118709     43.198544      4.196032         0.822362
# std      203.298980     12.279544      1.110031         0.382216
# min        0.000000     18.000000      1.000000         0.000000
# 25%      861.000000     34.000000      4.000000         1.000000
# 50%      936.000000     41.000000      5.000000         1.000000
# 75%     1078.000000     52.000000      5.000000         1.000000
# max     1205.000000     99.000000      5.000000         1.000000
#
#        Positive Feedback Count
# count             23486.000000
# mean                  2.535936
# std                   5.702202
# min                   0.000000
# 25%                   0.000000
# 50%                   1.000000
# 75%                   3.000000
# max                 122.000000

# %% [markdown]
# # DATA PREPROCESSING

# %% [markdown]
# # Checking and Filling Null Values.

# %%
#checking for null values
data.isna().sum()
# Out:
# Clothing ID                   0
# Age                           0
# Title                      3810
# Review Text                 845
# Rating                        0
# Recommended IND               0
# Positive Feedback Count       0
# Division Name                14
# Department Name              14
# Class Name                   14
# dtype: int64

# %%
#dropping the title column
data.drop('Title',inplace=True,axis=1)

# %%
data.isna().sum()
# Out:
# Clothing ID                  0
# Age                          0
# Review Text                845
# Rating                       0
# Recommended IND              0
# Positive Feedback Count      0
# Division Name               14
# Department Name             14
# Class Name                  14
# dtype: int64

# %%
#dropping the records where review text is null.
data=data[~data['Review Text'].isnull()]

# %%
data.isna().sum()
# Out:
# Clothing ID                 0
# Age                         0
# Review Text                 0
# Rating                      0
# Recommended IND             0
# Positive Feedback Count     0
# Division Name              13
# Department Name            13
# Class Name                 13
# dtype: int64

# %%
#Filling the missing values in Division Name, Department Name and Class Name using their respective mode.
def fillna(data,col):
    return data[col].fillna(data[col].mode()[0],inplace=True)
missing_cols=["Division Name","Department Name","Class Name"]
for i in missing_cols:
    fillna(data,i)

# %%
data.isna().sum()
# Out:
# Clothing ID                0
# Age                        0
# Review Text                0
# Rating                     0
# Recommended IND            0
# Positive Feedback Count    0
# Division Name              0
# Department Name            0
# Class Name                 0
# dtype: int64

# %% [markdown]
# Now there is no missing values.

# %% [markdown]
# # Numeric Columns

# %%
#finding the numerical columns in dataset
num_cols=[features for features in data.columns if data[features].dtypes !='O']
num_cols
# Out:
# ['Clothing ID', 'Age', 'Rating', 'Recommended IND', 'Positive Feedback Count']

# %%
#data of the numerical columns
data[num_cols]
# Out:
#        Clothing ID  Age  Rating  Recommended IND  Positive Feedback Count
# 0              767   33       4                1                        0
# 1             1080   34       5                1                        4
# 2             1077   60       3                0                        0
# 3             1049   50       5                1                        0
# 4              847   47       5                1                        6
# ...            ...  ...     ...              ...                      ...
# 23481         1104   34       5                1                        0
# 23482          862   48       3                1                        0
# 23483         1104   31       3                0                        1
# 23484         1084   28       3                1                        2
# 23485         1104   52       5                1                       22
#
# [22641 rows x 5 columns]

# %%
#finding how many unique values present in numerical columns
data[num_cols].nunique()
# Out:
# Clothing ID                1179
# Age                          77
# Rating                        5
# Recommended IND               2
# Positive Feedback Count      82
# dtype: int64

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Outliers

# %% [markdown]
# CHECKING FOR OUTLIERS IN NUMERICAL COLUMNS

# %%
#distplot of clothing id
sns.distplot(data['Clothing ID'])
# Out:
# <AxesSubplot:xlabel='Clothing ID', ylabel='Density'>

# %%
#box plot of clothing id
sns.boxplot(data['Clothing ID'])
# Out:
# <AxesSubplot:xlabel='Clothing ID'>

# %%
#distplot of age
sns.distplot(data['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
#box plot of age
sns.boxplot(data['Age'])
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
#count plot of ratings
sns.countplot(data['Rating'])
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='count'>

# %%
#box plot of ratings
sns.boxplot(data['Rating'])
# Out:
# <AxesSubplot:xlabel='Rating'>

# %%
#count plot of recommended ind
sns.countplot(data['Recommended IND'])
# Out:
# <AxesSubplot:xlabel='Recommended IND', ylabel='count'>

# %%
#box plot of recommended ind
sns.boxplot(data['Recommended IND'])
# Out:
# <AxesSubplot:xlabel='Recommended IND'>

# %%
#distplot of positive feedback count
sns.distplot(data['Positive Feedback Count'])
# Out:
# <AxesSubplot:xlabel='Positive Feedback Count', ylabel='Density'>

# %%
#box plot of positive feedback count
sns.boxplot(data['Positive Feedback Count'])
# Out:
# <AxesSubplot:xlabel='Positive Feedback Count'>

# %% [markdown]
# There are outliers.We need to handle the outliers of column containing continues values.

# %% [markdown]
# # Handling Outliers

# %% [markdown]
# CLOTHING ID

# %%
Q1=np.percentile(data['Clothing ID'],25, interpolation ='midpoint')
print(Q1)
Q2=np.percentile(data['Clothing ID'],50, interpolation ='midpoint')
print(Q2)
Q3=np.percentile(data['Clothing ID'],75, interpolation ='midpoint')
print(Q3)
IQR =Q3-Q1
IQR
low_limit = Q1-1.5*IQR
print(low_limit)
upper_limit =Q3+1.5*IQR
print(upper_limit)
# Out:
# 861.0
# 936.0
# 1078.0
# 535.5
# 1403.5

# %%
outlier = []
for x in data["Clothing ID"]:
    if ((x>upper_limit) or (x<low_limit)):
        outlier.append(x)
print(outlier)
# Out:
# [4, 89, 368, 368, 368, 126, 523, 329, 305, 127, 127, 127, 127, 127, 127, 149, 149, 204, 252, 252, 117, 117, 252, 252, 252, 252, 252, 252, 252, 117, 252, 252, 117, 245, 245, 2, 299, 80, 154, 154, 154, 158, 154, 154, 154, 154, 154, 154, 197, 59, 235, 59, 235, 230, 442, 442, 442, 411, 411, 411, 411, 411, 424, 485, 424, 115, 115, 434, 178, 225, 225, 225, 398, 225, 225, 431, 225, 34, 481, 481, 481, 481, 481, 481, 481, 371, 206, 321, 164, 164, 63, 160, 146, 146, 146, 146, 129, 129, 129, 129, 129, 418, 129, 418, 129, 129, 129, 517, 132, 132, 132, 132, 176, 248, 176, 248, 176, 176, 248, 176, 341, 341, 96, 14, 18, 282, 282, 282, 52, 282, 282, 282, 282, 282, 282, 282, 282, 282, 282, 282, 282, 282, 52, 282, 282, 282, 282, 282, 282, 282, 282, 282, 282, 282, 282, 282, 282, 282, 282, 282, 282, 282, 21, 491, 521, 486, 486, 20, 212, 429, 288, 302, 302, 505, 505, 374, 153, 505, 505, 374, 374, 374, 374, 285, 506, 412, 506, 506, 506, 506, 380, 380, 380, 380, 380, 512, 380, 422, 422, 422, 458, 468, 433, 433, 308, 464, 232, 232, 135, 135, 135, 135, 460, 460, 460, 460, 460, 460, 460, 460, 460, 460, 460, 460, 460, 448, 460, 460, 257, 257, 257, 270, 257, 257, 257, 257, 257, 257, 319, 121, 121, 121, 121, 121, 121, 144, 144, 144, 144, 56, 144, 173, 144, 413, 203, 107, 107, 107, 107, 107, 107, 107, 107, 495, 50, 495, 381, 381, 381, 381, 381, 273, 381, 381, 381, 381, 306, 327, 327, 306, 327, 463, 463, 363, 463, 463, 463, 363, 363, 334, 334, 373, 238, 404, 404, 404, 272, 462, 462, 462, 330, 155, 155, 155, 155, 155, 155, 155, 155, 155, 155, 155, 155, 155, 35, 35, 35, 410, 207, 211, 392, 392, 392, 201, 525, 5, 494, 138, 494, 360, 360, 360, 360, 385, 385, 246, 295, 295, 216, 295, 295, 170, 170, 150, 170, 170, 170, 150, 150, 150, 150, 336, 124, 124, 124, 336, 124, 124, 336, 336, 292, 294, 294, 294, 294, 292, 294, 292, 294, 179, 255, 255, 384, 255, 313, 352, 255, 251, 251, 251, 122, 251, 122, 251, 251, 251, 251, 191, 251, 251, 251, 191, 251, 251, 68, 511, 511, 511, 68, 13, 324, 366, 114, 340, 409, 183, 183, 118, 183, 183, 151, 502, 338, 30, 502, 439, 439, 439, 116, 116, 116, 116, 116, 105, 465, 475, 405, 189, 189, 346, 88, 516, 516, 137, 478, 478, 478, 478, 396, 396, 406, 406, 406, 406, 472, 472, 472, 47, 323, 472, 472, 71, 427, 177, 365, 435, 177, 70, 435, 177, 17, 365, 435, 113, 134, 134, 134, 205, 510, 510, 205, 510, 407, 397, 397, 407, 407, 312, 247, 260, 496, 243, 243, 243, 260, 260, 279, 279, 260, 243, 260, 260, 279, 279, 260, 260, 279, 260, 260, 279, 260, 260, 260, 260, 348, 359, 283, 283, 283, 283, 83, 61, 61, 57, 38, 265, 38, 265, 414, 133, 133, 318, 318, 72, 162, 162, 399, 219, 261, 498, 498, 498, 498, 376, 147, 376, 86, 376, 264, 147, 147, 131, 131, 131, 131, 131, 148, 148, 148, 254, 254, 254, 254, 254, 254, 254, 254, 254, 157, 157, 157, 87, 456, 456, 477, 456, 209, 315, 315, 22, 125, 437, 437, 125, 437, 119, 119, 119, 172, 172, 172, 172, 172, 172, 172, 172, 12, 356, 403, 403, 90, 90, 90, 90, 90, 208, 90, 90, 90, 90, 90, 90, 90, 90, 90, 375, 111, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 375, 141, 518, 518, 333, 333, 333, 333, 196, 196, 196, 78, 196, 79, 196, 473, 473, 303, 501, 501, 501, 501, 519, 287, 287, 91, 287, 287, 186, 301, 301, 301, 301, 110, 112, 377, 377, 377, 377, 377, 112, 377, 377, 377, 488, 258, 509, 509, 509, 509, 471, 415, 45, 267, 48, 175, 104, 370, 28, 370, 210, 304, 215, 215, 215, 215, 428, 423, 215, 215, 215, 215, 215, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 74, 444, 218, 444, 103, 347, 98, 167, 263, 167, 167, 167, 167, 167, 167, 393, 10, 253, 253, 253, 436, 280, 500, 492, 492, 281, 281, 281, 420, 420, 420, 420, 128, 128, 343, 128, 128, 343, 343, 128, 343, 343, 128, 25, 93, 93, 180, 180, 534, 180, 534, 185, 402, 139, 139, 139, 402, 139, 432, 174, 378, 378, 378, 378, 378, 378, 378, 480, 109, 109, 109, 109, 480, 480, 40, 40, 40, 441, 441, 332, 332, 332, 332, 332, 82, 82, 332, 332, 332, 332, 349, 194, 194, 194, 194, 194, 194, 194, 194, 194, 194, 194, 194, 194, ...

# %%
ind_1 =data["Clothing ID"]<low_limit
data.loc[ind_1].index
# Out:
# Int64Index([   29,    43,    56,    59,    61,   138,   157,   171,   216,
#               382,
#             ...
#             23425, 23435, 23438, 23449, 23457, 23461, 23463, 23469, 23471,
#             23476],
#            dtype='int64', length=1417)

# %%
data.drop(data.loc[ind_1].index,inplace =True)

# %%
sns.boxplot(data['Clothing ID'])
# Out:
# <AxesSubplot:xlabel='Clothing ID'>

# %% [markdown]
# AGE

# %%
Q1=np.percentile(data['Age'],25, interpolation ='midpoint')
print(Q1)
Q2=np.percentile(data['Age'],50, interpolation ='midpoint')
print(Q2)
Q3=np.percentile(data['Age'],75, interpolation ='midpoint')
print(Q3)
IQR =Q3-Q1
IQR
low_limit = Q1-1.5*IQR
print(low_limit)
upper_limit =Q3+1.5*IQR
print(upper_limit)
# Out:
# 34.0
# 41.0
# 52.0
# 7.0
# 79.0

# %%
outlier = []
for x in data["Age"]:
    if ((x>upper_limit) or (x<low_limit)):
        outlier.append(x)
print(outlier)
# Out:
# [83, 83, 83, 80, 82, 82, 83, 82, 85, 80, 85, 83, 84, 83, 83, 80, 83, 80, 80, 83, 84, 82, 82, 83, 81, 90, 85, 94, 83, 83, 86, 80, 85, 82, 89, 80, 99, 83, 83, 83, 82, 81, 91, 83, 83, 80, 91, 83, 80, 84, 83, 99, 82, 82, 83, 87, 83, 90, 83, 82, 82, 92, 91, 83, 83, 82, 85, 83, 85, 84, 83, 89, 93, 81, 94, 94, 83, 83, 82, 83, 91, 83, 83, 83, 83, 83, 87, 83, 81, 81, 83, 83, 84, 83, 83, 84, 80, 87, 83, 86]

# %%
ind_2=data["Age"]>upper_limit
data.loc[ind_2].index
# Out:
# Int64Index([   95,   234,   277,   628,   846,   958,  1006,  1036,  1188,
#              1199,  1616,  2006,  2119,  2447,  3069,  3291,  3301,  3596,
#              3810,  3820,  4418,  4968,  5368,  5371,  5469,  5901,  5909,
#              6543,  6763,  6829,  6973,  7147,  7292,  7346,  8078,  8109,
#              8327,  8718,  8877,  9085,  9161,  9437,  9513,  9815,  9896,
#             10470, 10617, 10805, 11181, 11245, 11364, 11545, 11692, 11947,
#             12003, 12581, 12612, 12631, 13022, 13383, 14404, 14997, 15802,
#             16163, 16190, 16318, 16323, 16713, 16780, 17303, 17401, 17412,
#             17578, 17611, 18036, 18563, 18894, 18963, 19179, 19257, 19304,
#             19470, 20043, 20077, 20413, 20460, 21254, 21437, 21719, 22085,
#             22129, 22228, 22421, 22435, 22436, 22552, 22640, 22716, 22773,
#             23033],
#            dtype='int64')

# %%
data.drop(data.loc[ind_2].index,inplace =True)

# %%
sns.boxplot(data['Age'])
# Out:
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# POSITIVE FEEDBACK COUNT

# %%
Q1=np.percentile(data['Positive Feedback Count'],25, interpolation ='midpoint')
print(Q1)
Q2=np.percentile(data['Positive Feedback Count'],50, interpolation ='midpoint')
print(Q2)
Q3=np.percentile(data['Positive Feedback Count'],75, interpolation ='midpoint')
print(Q3)
IQR =Q3-Q1
IQR
low_limit = Q1-1.5*IQR
print(low_limit)
upper_limit =Q3+1.5*IQR
print(upper_limit)
# Out:
# 0.0
# 1.0
# 3.0
# -4.5
# 7.5

# %%
outlier = []
for x in data["Positive Feedback Count"]:
    if ((x>upper_limit) or (x<low_limit)):
        outlier.append(x)
print(outlier)
# Out:
# [14, 14, 9, 34, 9, 10, 9, 17, 9, 11, 11, 24, 12, 9, 8, 9, 8, 9, 9, 17, 10, 14, 13, 8, 20, 11, 16, 8, 23, 13, 17, 9, 15, 17, 10, 13, 11, 9, 20, 9, 11, 9, 14, 19, 10, 15, 11, 8, 29, 32, 12, 30, 11, 12, 11, 8, 8, 55, 10, 17, 84, 12, 11, 9, 14, 27, 14, 8, 43, 11, 15, 14, 21, 42, 29, 12, 8, 12, 14, 24, 15, 37, 13, 17, 11, 9, 9, 11, 11, 10, 8, 12, 12, 12, 10, 11, 9, 11, 15, 8, 10, 14, 13, 11, 9, 8, 8, 17, 12, 9, 30, 10, 8, 8, 34, 55, 10, 71, 9, 19, 10, 14, 16, 9, 11, 35, 65, 8, 117, 19, 8, 8, 16, 33, 9, 9, 10, 9, 8, 13, 8, 21, 19, 24, 17, 8, 8, 12, 15, 15, 14, 8, 9, 15, 20, 8, 11, 18, 12, 33, 11, 25, 12, 12, 13, 20, 10, 27, 10, 8, 8, 17, 10, 47, 12, 9, 13, 16, 14, 13, 15, 10, 11, 8, 37, 11, 24, 17, 8, 22, 13, 10, 12, 9, 51, 10, 19, 21, 14, 29, 8, 94, 10, 27, 15, 8, 9, 9, 11, 9, 9, 9, 31, 31, 9, 10, 30, 8, 18, 9, 77, 23, 61, 46, 8, 10, 14, 20, 11, 10, 26, 13, 24, 8, 19, 27, 9, 19, 8, 12, 9, 17, 12, 13, 28, 25, 28, 8, 8, 10, 14, 10, 9, 9, 9, 23, 16, 10, 42, 9, 26, 11, 46, 20, 17, 10, 12, 9, 27, 30, 26, 14, 10, 9, 11, 11, 8, 30, 14, 13, 9, 12, 17, 15, 17, 8, 9, 10, 8, 11, 9, 36, 10, 18, 31, 12, 12, 18, 15, 17, 15, 21, 10, 8, 17, 11, 57, 45, 11, 20, 8, 9, 15, 11, 11, 28, 8, 9, 66, 14, 22, 23, 22, 11, 16, 17, 11, 14, 11, 13, 8, 29, 11, 13, 10, 14, 13, 16, 14, 9, 9, 14, 12, 16, 11, 37, 82, 21, 17, 14, 9, 12, 14, 8, 35, 9, 9, 9, 14, 18, 23, 16, 8, 9, 10, 8, 8, 17, 26, 15, 18, 25, 34, 10, 19, 11, 9, 27, 9, 27, 11, 15, 12, 28, 19, 17, 9, 26, 35, 30, 15, 44, 81, 31, 11, 15, 13, 9, 15, 17, 10, 14, 58, 25, 9, 27, 16, 17, 14, 15, 8, 18, 14, 18, 16, 19, 13, 78, 9, 11, 17, 10, 38, 12, 17, 31, 18, 19, 14, 14, 9, 8, 37, 26, 12, 12, 23, 13, 12, 19, 26, 12, 17, 9, 10, 9, 32, 27, 14, 11, 11, 17, 32, 11, 21, 9, 45, 14, 17, 15, 18, 21, 10, 8, 8, 49, 13, 10, 30, 8, 29, 12, 8, 14, 8, 32, 10, 24, 10, 8, 37, 8, 32, 9, 28, 11, 9, 14, 8, 20, 19, 11, 15, 13, 34, 10, 18, 8, 8, 8, 19, 28, 14, 10, 11, 18, 16, 8, 15, 28, 10, 23, 9, 16, 35, 9, 16, 10, 18, 14, 25, 9, 11, 16, 26, 23, 19, 8, 8, 17, 10, 11, 20, 11, 23, 8, 15, 11, 11, 15, 9, 10, 10, 11, 12, 10, 8, 17, 8, 9, 15, 17, 11, 13, 8, 17, 10, 16, 10, 25, 8, 51, 19, 12, 12, 30, 9, 18, 10, 16, 21, 8, 11, 21, 19, 9, 17, 52, 8, 11, 8, 16, 9, 11, 16, 11, 18, 9, 11, 9, 16, 13, 8, 21, 18, 20, 8, 11, 10, 10, 8, 17, 15, 32, 22, 12, 10, 11, 8, 8, 19, 14, 12, 11, 9, 9, 11, 11, 15, 8, 12, 10, 25, 122, 10, 20, 8, 10, 8, 14, 9, 10, 12, 22, 41, 15, 14, 8, 8, 8, 11, 12, 12, 11, 14, 18, 8, 16, 18, 10, 14, 25, 13, 19, 8, 20, 14, 11, 9, 17, 13, 12, 12, 14, 15, 21, 9, 108, 9, 49, 12, 8, 8, 10, 13, 8, 14, 16, 9, 9, 8, 13, 10, 18, 32, 51, 9, 10, 26, 14, 8, 8, 8, 10, 14, 8, 9, 9, 12, 14, 12, 13, 31, 14, 15, 10, 16, 10, 12, 10, 11, 8, 10, 22, 9, 17, 18, 15, 16, 23, 14, 47, 10, 9, 10, 8, 15, 20, 9, 54, 14, 14, 40, 36, 11, 24, 10, 16, 11, 14, 11, 8, 9, 8, 65, 9, 30, 8, 53, 9, 11, 26, 87, 29, 20, 22, 17, 18, 9, 10, 10, 8, 11, 31, 36, 64, 22, 14, 10, 18, 18, 12, 12, 8, 8, 13, 16, 19, 8, 12, 8, 11, 15, 13, 8, 17, 19, 15, 20, 14, 33, 13, 13, 10, 9, 13, 10, 9, 8, 12, 24, 13, 8, 11, 16, 10, 40, 13, 8, 10, 14, 14, 8, 16, 17, 9, 89, 8, 9, 11, 25, 9, 22, 12, 23, 13, 12, 9, 8, 42, 12, 8, 10, 19, 26, 22, 24, 24, 12, 15, 8, 17, 14, 15, 22, 9, 11, 16, 9, 10, 11, 44, 17, 8, 14, 17, 9, 30, 8, 9, 22, 27, 9, 37, 57, 8, 10, 68, 16, 23, 8, 14, 24, 15, 11, 9, 24, 9, 8, 15, 22, 9, 10, 21, 15, 16, 28, 10, 14, 19, 16, 8, 16, 17, 10, 14, 9, 25, 10, 11, 15, 20, 11, 8, 11, 17, 9, 12, 8, 12, 18, 12, 65, 14, 9, 19, 8, 8, 8, 15, 9, 8, 20, 12, 9, 17, 9, 8, 17, 11, 10, 9, 10, 8, 16, 9, 9, 16, 8, 8, 16, 10, 16, 10, 28, 22, 8, 23, 9, 8, 11, 12, 21, 10, 21, 8, 8, 15, 12, 12, 28, 17, 9, 42, 14, 18, 10, 24, 13, 44, 35, 8, 10, 14, 8, 16, 9, 22, 18, 9, 14, 18, 10, 9, 10, 19, 8, 34, 13, 16, 10, 15, 30, 15, 15, 10, 10, 18, 9, 17, 11, 14, 37, 10, 11, 10, 26, 41, 12, 23, 81, 10, 10, 20, 10, 9, 8, 22, 9, 15, 14, 8, 14, 8, 8, 9, 11, 27, 11, 8, 17, 19, 19, 31, 12, 13, 11, 9, 12, 29, 24, 38, 11, 10, 11, 9, 16, 8, 15, 10, 8, 11, 8, 8, 17, 9, 8, 12, 9, 12, 25, 8, 15, 13, 9, 9, 10, 11,  ...

# %%
ind_3=data["Positive Feedback Count"]>upper_limit
data.loc[ind_3].index
# Out:
# Int64Index([   10,    21,    44,    53,    66,    70,    87,    99,   103,
#               106,
#             ...
#             23382, 23386, 23394, 23398, 23422, 23427, 23433, 23441, 23467,
#             23485],
#            dtype='int64', length=2042)

# %%
data.drop(data.loc[ind_3].index,inplace =True)

# %%
sns.boxplot(data['Positive Feedback Count'])
# Out:
# <AxesSubplot:xlabel='Positive Feedback Count'>

# %% [markdown]
# # EDA

# %% [markdown]
# # Univariate Visualization

# %%
# Converting 0 & 1 in Not Recommended & Recommended
data.loc[data['Recommended IND'] == 0, 'Recommended IND'] = "Not Recommended" 
data.loc[data['Recommended IND'] == 1, 'Recommended IND'] = "Recommended"
plt.figure(figsize = (6,4))
x = data['Recommended IND'].value_counts()
labels = 'Recommended','Not Recommended'
plt.pie(x = x,  labels = labels,
        autopct = '%.2f%%', 
        textprops = {'size' : 'x-large',
                   'fontweight' : 'bold'})
plt.title('Distribution of Recomended ID', fontsize = 14, fontweight = 'bold')
plt.legend(labels, loc="upper left", bbox_to_anchor = (1,1))
plt.tight_layout()
plt.show()

# %% [markdown]
# 82% of the data we have been recommended to customers means the data is of good quality.

# %% [markdown]
# UNIVARIATE VISUALIZATION FOR NUMERICAL DATA.

# %%
data.hist(bins=10, color='steelblue', edgecolor='black', linewidth=1.0,
           xlabelsize=8, ylabelsize=8, grid=False)    
plt.tight_layout(rect=(0, 0, 2, 2))

# %% [markdown]
# As we take a look at the graph Clothing Id has way more skewness.
#
# Age has skewness.
#
# Rating we do have a product that has fewer ratings but mostly data is in 5 ratings.
#
# Recommended IND Mostly product is Recommended to customer

# %% [markdown]
# UNIVARIATE VISUALIZATION FOR CATEGORICAL DATA

# %%
cat_cols= data[['Division Name', 'Department Name','Class Name']]

# %%
cat_cols
# Out:
#         Division Name Department Name Class Name
# 0           Initmates        Intimate  Intimates
# 1             General         Dresses    Dresses
# 2             General         Dresses    Dresses
# 3      General Petite         Bottoms      Pants
# 4             General            Tops    Blouses
# ...               ...             ...        ...
# 23479  General Petite         Bottoms     Skirts
# 23481  General Petite         Dresses    Dresses
# 23482  General Petite            Tops      Knits
# 23483  General Petite         Dresses    Dresses
# 23484         General         Dresses    Dresses
#
# [19082 rows x 3 columns]

# %%
plt.figure(figsize=[14,10])
n=1
for x in cat_cols:
    plt.subplot(2,2,n)
    sns.countplot(x=data[x],data=data)
    sns.despine()
    plt.title("Distribution of {} ".format(x), fontsize=16, fontweight='bold')
    plt.xticks(rotation=55)
    n=n+1
plt.tight_layout()
plt.show()

# %% [markdown]
# Division Name: General products are more in demand than intimate products
#
# Department Name: Most choose products are Tops & Dresses
#
# Class Name: Dresses, Knits, and Blouses are the most popular

# %% [markdown]
# Univariate distribution of clothing ID

# %%
plt.figure(figsize=(8,6))
ax = sns.countplot(x='Clothing ID', data = data, 
                   order = data['Clothing ID'].value_counts().index[:50])
plt.title(' Distribution of Top 50 Clothing ID ', fontsize = 16, fontweight = 'bold')
plt.xlabel('Count', fontsize = 13)
plt.xticks(rotation=90)
plt.ylabel('Clothing ID Number', fontsize = 13)
plt.tight_layout()
plt.show()

# %% [markdown]
# Plotting Top 50 clothing Id so we know which type of clothes are in demand.

# %% [markdown]
# # Bivariate Visualization

# %% [markdown]
# Division, Department & Class Name Vs Recommended IND

# %%
for x in cat_cols:
    y = pd.crosstab(data[x],data['Recommended IND'])
    y.div(y.sum(1).astype(float), axis=0)
    y.plot(kind='bar', stacked=True)
    plt.title("Distribution of {} vs Recommended IND".format(x), fontsize=16, fontweight='bold')
    plt.xticks(rotation=55)

# %% [markdown]
# Division Name: Recommendation clothes are more for General products
#
# Department Name: Jackets are the only products which have less recommended compared to other clothes.
#
# Class Name: Interesting result is Trend clothes are only recommended we don't have any negative review.

# %% [markdown]
# Age, Positive Feedback Count Vs Recommended IND

# %%
plt.figure(figsize=[17,10])
n=1
label = data[['Age', 'Positive Feedback Count']]
for x in label:
    plt.subplot(2,1,n)
    sns.countplot(x=data[x], hue='Recommended IND',data=data)
    sns.despine()
    plt.title("Frequency count of {} ".format(x), fontsize=16, fontweight='bold')
    plt.xticks(rotation=90)
    n=n+1
plt.tight_layout()
plt.show()

# %% [markdown]
# At age of 39 highest people recommend the product. The age range between 30 to 50 has the highest number of people recommending the product.
#
# Positive Feedback Count doesn’t give much of the information.

# %% [markdown]
# Division, Department & Class Name Vs Rating

# %%
for x in cat_cols:
    y = pd.crosstab(data[x],data['Rating'])
    y.div(y.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
    plt.title("Distribution of {} vs Rating ".format(x), fontsize=16, fontweight='bold')

# %% [markdown]
# The lowest rating 1 & 2 are given to General products, while most 5 ratings are given to Intimates
# Trend clothes has lowest 5 ratings compared to another different department name
# Casual bottoms and chemises are giving the highest 4-star rating and don’t have any other rating that's strange.

# %% [markdown]
# Age Vs Rating

# %%
df=data.copy()
bins = np.arange(0,100,10)
df['Age group'] = pd.cut(df['Age'], bins)
df.columns
df= df.groupby(['Rating', df['Age group']]).size().reset_index(name='n')
df.columns
ratings_count_data_pivot = pd.pivot_table(df,index=["Age group"],
               values=["n"],
               columns=["Rating"],
               aggfunc=[np.sum])
ratings_count_data_pivot.plot(kind = 'bar', stacked=True, fontsize = 14)
plt.title('Age vs Rating', fontweight='bold', fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Age vs Rating')

# %% [markdown]
# Division, Department & Class Name Vs Age

# %%
plt.figure(figsize=[8,10])
n=1
for x in cat_cols:
    plt.subplot(3,1,n)
    sns.boxplot(x=data[x], y='Age',data=data)
    sns.despine()
    plt.title("Frequency count of {} Vs Age".format(x), fontsize=16, fontweight='bold')
    plt.xticks(rotation=55)
    n=n+1
plt.tight_layout()
plt.show()

# %% [markdown]
# People in the range of age of 30–40 are buying product frequently.
#
# Tops are brought by people having age of 60–70. Trendy clothes are not preferable by aged people.
#
# Swimsuit is brought by at age of around 90 which is pretty rare.

# %% [markdown]
# # ENCODING

# %% [markdown]
# LABEL ENCODING

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
a=['Division Name','Department Name','Class Name','Recommended IND']
for i in np.arange(len(a)):    
    data[a[i]] = label.fit_transform(data[a[i]])

# %%
data.head()
# Out:
#    Clothing ID  Age                                        Review Text  \
# 0          767   33  Absolutely wonderful - silky and sexy and comf...
# 1         1080   34  Love this dress!  it's sooo pretty.  i happene...
# 2         1077   60  I had such high hopes for this dress and reall...
# 3         1049   50  I love, love, love this jumpsuit. it's fun, fl...
# 4          847   47  This shirt is very flattering to all due to th...
#
#    Rating  Recommended IND  Positive Feedback Count  Division Name  \
# 0       4                1                        0              2
# 1       5                1                        4              0
# 2       3                0                        0              0
# 3       5                1                        0              1
# 4       5                1                        6              0
#
#    Department Name  Class Name
# 0                2           3
# 1                1           1
# 2                1           1
# 3                0          11
# 4                4           0

# %% [markdown]
# # Feature Reduction

# %%
cor_matrix=data.corr()
plt.subplots(figsize=(20,8))
sns.heatmap(cor_matrix,annot=True,linewidths=0.2,cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
cor_matrix=data.corr()
plt.subplots(figsize=(20,8))
sns.heatmap(cor_matrix,vmin=-0.7,vmax=1,annot=True,linewidths=0.2,cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
data.columns
# Out:
# Index(['Clothing ID', 'Age', 'Review Text', 'Rating', 'Recommended IND',
#        'Positive Feedback Count', 'Division Name', 'Department Name',
#        'Class Name'],
#       dtype='object')

# %% [markdown]
# # MODELLING

# %% [markdown]
# SPLITTING DATA

# %%
y=data['Recommended IND']
x=data.drop(['Recommended IND','Review Text'],axis=1)
from sklearn.model_selection import train_test_split
x_train, x_test , y_train, y_test = train_test_split(x, y, random_state=42, test_size = 0.2)

# %%
x.columns
# Out:
# Index(['Clothing ID', 'Age', 'Rating', 'Positive Feedback Count',
#        'Division Name', 'Department Name', 'Class Name'],
#       dtype='object')

# %%
x_train.shape
# Out:
# (15265, 7)

# %%
y_train.shape
# Out:
# (15265,)

# %%
x_test.shape
# Out:
# (3817, 7)

# %%
y_test.shape
# Out:
# (3817,)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
logit_model=LogisticRegression()
logit_model.fit(x_train, y_train) 
y_pred=logit_model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,f1_score

# %%
print("Accuracy is: ",accuracy_score(y_test,y_pred))
print("Precision is: ",precision_score(y_test,y_pred))
print("Recall is: ",recall_score(y_test,y_pred))
print("f1 score is: ",f1_score(y_test,y_pred))
# Out:
# Accuracy is:  0.9305737490175531
# Precision is:  0.9567016873607131
# Recall is:  0.9588385449904275
# f1 score is:  0.9577689243027888

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[ 547,  136],
#        [ 129, 3005]], dtype=int64)

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
acc_values=[]
neighbors=np.arange(3,15)
for k in neighbors:
    classifier=KNeighborsClassifier(n_neighbors=k,metric='minkowski')
    classifier.fit(x_train,y_train)
    y_pred=classifier.predict(x_test)
    acc=accuracy_score(y_test,y_pred)
    acc_values.append(acc)

# %%
acc_values
# Out:
# [0.8842022530783338,
#  0.8891799842808489,
#  0.8847262247838616,
#  0.8912758711029605,
#  0.8752947340843594,
#  0.8826303379617501,
#  0.8703170028818443,
#  0.8760806916426513,
#  0.8679591302069688,
#  0.8716269321456641,
#  0.8614094838878701,
#  0.8635053707099817]

# %%
plt.plot(neighbors,acc_values,'o-')
plt.xlabel('k value')
plt.ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %% [markdown]
# MODEL FINE TUNING

# %%
#giving k value as 6
classifier=KNeighborsClassifier(n_neighbors=6,metric='minkowski')
classifier.fit(x_train,y_train)
y_pred=classifier.predict(x_test)

# %%
print("Accuracy is: ",accuracy_score(y_test,y_pred))
print("Precision is: ",precision_score(y_test,y_pred))
print("Recall is: ",recall_score(y_test,y_pred))
print("f1 score is: ",f1_score(y_test,y_pred))
# Out:
# Accuracy is:  0.8912758711029605
# Precision is:  0.9013876586950104
# Recall is:  0.9741544352265475
# f1 score is:  0.9363594540714614

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[ 349,  334],
#        [  81, 3053]], dtype=int64)

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dt_model=DecisionTreeClassifier()
dt_model.fit(x_train,y_train)
y_pred=dt_model.predict(x_test)
print("Accuracy is: ",accuracy_score(y_test,y_pred))
print("Precision is: ",precision_score(y_test,y_pred))
print("Recall is: ",recall_score(y_test,y_pred))
print("f1 score is: ",f1_score(y_test,y_pred))
# Out:
# Accuracy is:  0.9177364422321195
# Precision is:  0.9499042756860242
# Recall is:  0.9499042756860242
# f1 score is:  0.9499042756860242

# %%
y_test.value_counts()
# Out:
# 1    3134
# 0     683
# Name: Recommended IND, dtype: int64

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[ 526,  157],
#        [ 157, 2977]], dtype=int64)

# %% [markdown]
# # SUPPORT VECTOR MACHINE

# %% [markdown]
# # Linear SVM

# %%
from sklearn.svm import SVC
svm_linear = SVC(kernel='linear')
svm_linear.fit(x_train,y_train)
y_pred=svm_linear.predict(x_test)
print("Accuracy is: ",accuracy_score(y_test,y_pred))
print("Precision is :",precision_score(y_test,y_pred))
print("Recall is :",recall_score(y_test,y_pred))
print("f1 score is :",f1_score(y_test,y_pred))
# Out:
# Accuracy is:  0.9386953104532355
# Precision is : 0.9908598510494245
# Recall is : 0.9339502233567326
# f1 score is : 0.9615637319316689

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[ 656,   27],
#        [ 207, 2927]], dtype=int64)

# %% [markdown]
# # Polynomial SVM

# %%
svm_poly=SVC(kernel='poly',degree=3)
svm_poly.fit(x_train,y_train)
y_pred=svm_poly.predict(x_test)
print("Accuracy  is: ",accuracy_score(y_test,y_pred))
print("Precision is :",precision_score(y_test,y_pred))
print("Recall is :",recall_score(y_test,y_pred))
print("f1 score is :",f1_score(y_test,y_pred))
# Out:
# Accuracy  is:  0.8210636625622216
# Precision is : 0.8210636625622216
# Recall is : 1.0
# f1 score is : 0.901740756725651

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[   0,  683],
#        [   0, 3134]], dtype=int64)

# %% [markdown]
# # Radial SVM

# %%
svm_radial = SVC(kernel='rbf')
svm_radial.fit(x_train,y_train)
y_pred=svm_radial.predict(x_test)
print("Accuracy is: ",accuracy_score(y_test,y_pred))
print("Precision is :",precision_score(y_test,y_pred))
print("Recall is :",recall_score(y_test,y_pred))
print("f1 score is :",f1_score(y_test,y_pred))
# Out:
# Accuracy is:  0.8210636625622216
# Precision is : 0.8210636625622216
# Recall is : 1.0
# f1 score is : 0.901740756725651

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[   0,  683],
#        [   0, 3134]], dtype=int64)

# %% [markdown]
# # RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(x_train, y_train)
y_pred = rfc.predict(x_test)
print("Accuracy  is: ",accuracy_score(y_test,y_pred))
print("Precision is :",precision_score(y_test,y_pred))
print("Recall is :",recall_score(y_test,y_pred))
print("f1 score is: ",f1_score(y_test,y_pred))
# Out:
# Accuracy  is:  0.9321456641341368
# Precision is : 0.9605895546299263
# Recall is : 0.9566049776643267
# f1 score is:  0.9585931254996004

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[ 560,  123],
#        [ 136, 2998]], dtype=int64)

# %% [markdown]
# We have tried out 5 different models and the accuracy scores for each of the model are as follows :
# Logistic regression:93%
#                 KNN:89%
#                 SVM:94%(linear),82%(polynomial and radial)
# Decisiontree classifier:92%
#     random forest:93%
#
#   So the best model is Linear SVM.

# %% [markdown]
# # FINE TUNING

# %% [markdown]
# # Hyperparameter tuning with GridSerach

# %%
from sklearn.model_selection import GridSearchCV

# %%
#List Hyperparameters that we want to tune.
leaf_size = list(range(1,5))
n_neighbors = list(range(3,4))
p=[1,2]
#Convert to dictionary
hyperparameters = dict(leaf_size=leaf_size, n_neighbors=n_neighbors, p=p)
#Create new KNN object
knn_2 = KNeighborsClassifier()

# %%
#Use GridSearch
clf = GridSearchCV(knn_2, hyperparameters, cv=10)
#Fit the model
best_model = clf.fit(x_train,y_train)
#Print The value of best Hyperparameters
print('Best leaf_size:', best_model.best_estimator_.get_params()['leaf_size'])
print('Best p:', best_model.best_estimator_.get_params()['p'])
print('Best n_neighbors:', best_model.best_estimator_.get_params()['n_neighbors'])
# Out:
# Best leaf_size: 4
# Best p: 2
# Best n_neighbors: 3

# %%
classifier=KNeighborsClassifier(leaf_size=1,n_neighbors=3,metric="minkowski",p=1)
model=classifier.fit(x_train,y_train)
y_pred=model.predict(x_test)
confusion_matrix(y_test, y_test)
# Out:
# array([[ 683,    0],
#        [   0, 3134]], dtype=int64)
